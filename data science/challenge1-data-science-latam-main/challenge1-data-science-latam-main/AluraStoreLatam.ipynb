# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ##Análisis de venta total en Tienda 1

# %%
tienda1_venta_total = tienda['Precio'].sum()
print("La venta total de la tienda 1 es de ", tienda1_venta_total)
# Out:
# La venta total de la tienda 1 es de  1150880400.0

# %%
tienda2_venta_total = tienda2['Precio'].sum()
print("La venta total de la tienda 2 es de ", tienda2_venta_total)
# Out:
# La venta total de la tienda 2 es de  1116343500.0

# %%
tienda3_venta_total = tienda3['Precio'].sum()
print("La venta total de la tienda 3 es de ", tienda3_venta_total)
# Out:
# La venta total de la tienda 3 es de  1098019600.0

# %%
tienda4_venta_total = tienda4['Precio'].sum()
print("La venta total de la tienda 4 es de ", tienda4_venta_total)
# Out:
# La venta total de la tienda 4 es de  1038375700.0

# %%
ventas_totales = pd.Series({
    'Tienda 1': tienda1_venta_total,
    'Tienda 2': tienda2_venta_total,
    'Tienda 3': tienda3_venta_total,
    'Tienda 4': tienda4_venta_total
})

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ### En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
tienda.Producto.unique()
# Out:
# array(['Asistente virtual', 'Mesa de comedor', 'Juego de mesa',
#        'Microondas', 'Silla de oficina', 'Bloques de construcción',
#        'Muñeca bebé', 'Lavavajillas', 'Lavadora de ropa',
#        'Carrito de control remoto', 'Refrigerador', 'Auriculares',
#        'Olla de presión', 'Bicicleta', 'Ciencia de datos con Python',
#        'Balón de voleibol', 'Ajedrez de madera', 'TV LED UHD 4K',
#        'Vaso térmico', 'Kit de bancas', 'Dashboards con Power BI',
#        'Cubertería', 'Set de ollas', 'Batería', 'Cuerda para saltar',
#        'Estufa', 'Cama box', 'Impresora', 'Mesa de noche', 'Armario',
#        'Dinosaurio Rex', 'Guitarra eléctrica', 'Secadora de ropa',
#        'Sofá reclinable', 'Tablet ABXY', 'Cubo mágico 8x8',
#        'Set de vasos', 'Modelado predictivo', 'Iphone 15', 'Mochila',
#        'Balón de baloncesto', 'Auriculares con micrófono', 'Sillón',
#        'Guitarra acústica', 'Iniciando en programación', 'Celular ABXY',
# ...

# %%
tienda1_productos_populares = tienda.Producto.value_counts()
tienda1_productos_populares
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %%
tienda2_productos_populares = tienda2.Producto.value_counts()
tienda2_productos_populares
# Out:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# ...

# %%
tienda3_productos_populares = tienda3.Producto.value_counts()
tienda3_productos_populares
# Out:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# ...

# %%
tienda4_productos_populares = tienda4.Producto.value_counts()
tienda4_productos_populares
# Out:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# ## En este paso, debes calcular las calificaciones promedio de los clientes para cada tienda. El objetivo es conocer la satisfacción del cliente con los productos vendidos.

# %%
tienda1_rate_promedio = tienda.Calificación.mean()
print("La Calificación promedio de la tienda 1 es de: ", tienda1_rate_promedio, "/5")
# Out:
# La Calificación promedio de la tienda 1 es de:  3.976685036032217 /5

# %%
tienda2_rate_promedio = tienda2.Calificación.mean()
print("La Calificación promedio de la tienda 2 es de: ", tienda2_rate_promedio, "/5")
# Out:
# La Calificación promedio de la tienda 2 es de:  4.037303942348453 /5

# %%
tienda3_rate_promedio = tienda3.Calificación.mean()
print("La Calificación promedio de la tienda 3 es de: ", tienda3_rate_promedio, "/5")
# Out:
# La Calificación promedio de la tienda 3 es de:  4.048325561678677 /5

# %%
tienda4_rate_promedio = tienda4.Calificación.mean()
print("La Calificación promedio de la tienda 4 es de: ", tienda4_rate_promedio, "/5")
# Out:
# La Calificación promedio de la tienda 4 es de:  3.9957591178965224 /5

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ## En este paso, debes identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualiza los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %% [markdown]
# ###Los 10 productos más vendidos en la tienda 1 son:

# %%
tienda1_productos_populares.head(10)
# Out:
# Producto
# Microondas                 60
# TV LED UHD 4K              60
# Armario                    60
# Secadora de ropa           58
# Mesa de noche              56
# Bloques de construcción    56
# Balón de baloncesto        55
# Bicicleta                  54
# Vaso térmico               54
# Refrigerador               54
# Name: count, dtype: int64

# %% [markdown]
# ### Los 10 productos menos vendidos en la tienda 1 son:

# %%
tienda1_productos_populares.tail(10)
# Out:
# Producto
# Muñeca bebé                    40
# Mesa de comedor                40
# Dinosaurio Rex                 40
# Cuerda para saltar             40
# Mochila                        39
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %% [markdown]
# ###Los 10 productos más vendidos en la tienda 2 son:

# %%
tienda2_productos_populares.head(10)
# Out:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Secadora de ropa             57
# Iphone 15                    55
# Bloques de construcción      54
# Armario                      54
# Set de ollas                 52
# Name: count, dtype: int64

# %% [markdown]
# ###Los 10 productos menos vendidos de la tienda 2 son:

# %%
tienda2_productos_populares.tail(10)
# Out:
# Producto
# Dinosaurio Rex       42
# Celular ABXY         41
# Smart TV             40
# Cubertería           39
# Asistente virtual    38
# Auriculares          37
# Sillón               35
# Mesa de comedor      34
# Impresora            34
# Juego de mesa        32
# Name: count, dtype: int64

# %% [markdown]
# ###Los 10 productos más vendidos de la tienda 3 son:

# %%
tienda3_productos_populares.head(10)
# Out:
# Producto
# Kit de bancas                57
# Mesa de comedor              56
# Cama king                    56
# Set de ollas                 55
# Mesa de noche                55
# Smart TV                     54
# Estufa                       53
# Cuerda para saltar           53
# Modelado predictivo          53
# Carrito de control remoto    52
# Name: count, dtype: int64

# %% [markdown]
# ### Los 10 productos menos vendidos de la tienda 3 son:

# %%
tienda3_productos_populares.head(10)
# Out:
# Producto
# Kit de bancas                57
# Mesa de comedor              56
# Cama king                    56
# Set de ollas                 55
# Mesa de noche                55
# Smart TV                     54
# Estufa                       53
# Cuerda para saltar           53
# Modelado predictivo          53
# Carrito de control remoto    52
# Name: count, dtype: int64

# %% [markdown]
# ### Los 10 productos más vendidos de la tienda 4 son:

# %%
tienda4_productos_populares.head(10)
# Out:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Mesa de comedor              55
# Mesa de noche                55
# Smart TV                     54
# Bloques de construcción      54
# Pandereta                    52
# Name: count, dtype: int64

# %% [markdown]
# ###Los 10 productos menos vendidos de la tienda 4 son:

# %%
tienda4_productos_populares.tail(10)
# Out:
# Producto
# Silla de oficina               40
# Celular ABXY                   39
# Ajedrez de madera              39
# Smartwatch                     39
# Lavadora de ropa               38
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# ## En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda.  Sabiendo que el cliente paga el envío.

# %%
print("El costo de envio de la tienda 1 es de:", tienda['Costo de envío'].mean())
# Out:
# El costo de envio de la tienda 1 es de: 26018.60958033065

# %%
print("El costo de envio de la tienda 2 es de: ", tienda2['Costo de envío'].mean())
# Out:
# El costo de envio de la tienda 2 es de:  25216.235693090293

# %%
print("El costo de envio de la tienda 3 es de: ", tienda3['Costo de envío'].mean())
# Out:
# El costo de envio de la tienda 3 es de:  24805.680373039424

# %%
print("El costo de envio de la tienda 4 es de: ", tienda4['Costo de envío'].mean())
# Out:
# El costo de envio de la tienda 4 es de:  23459.457167090754

# %% [markdown]
# #Visualización

# %% [markdown]
# ## Gráficos

# %% [markdown]
# ##Ventas totales por tienda

# %%
ventas_totales.plot(kind='pie', figsize=(12,8), color='blue')
# Out:
# <Axes: >

# %% [markdown]
# ##Productos populares por tienda

# %%
productos_combinados = pd.concat([tienda1_productos_populares.rename('Tienda 1'),
                                  tienda2_productos_populares.rename('Tienda 2'),
                                  tienda3_productos_populares.rename('Tienda 3'),
                                  tienda4_productos_populares.rename('Tienda 4')],
                                 axis = 1)

productos_graficar = productos_combinados.head(10)

productos_graficar.plot(kind='barh', figsize=(12,10))
# Out:
# <Axes: ylabel='Producto'>

# %% [markdown]
# ##Valoración promedio por tienda

# %%
tiendas_rating_series = pd.Series({
    'Tienda 1': tienda1_rate_promedio,
    'Tienda 2': tienda2_rate_promedio,
    'Tienda 3': tienda3_rate_promedio,
    'Tienda 4': tienda4_rate_promedio
})

tiendas_rating_series.plot(kind= 'bar', figsize=(12,8), color = 'green')
# Out:
# <Axes: >

# %% [markdown]
# #Informe final

# %% [markdown]
# El exhaustivo análisis llevado a cabo sobre el desemepeño de cada una de las tiendas sucursales de la franquicia de Don Juan se llevó a cabo con la finalidad de ayudar a este último a reconocer cuál de sus tiendas sería conveniente vender.
#
# Estos fueron los resultados que el presente análisis ha arrojado, los cuales fueron unos datos increiblemente cercanos entre cada tienda, ya que cada una de estas se desempeñaba de una manera similar en cuanto a ventas, productos y calificaciones.
#
# Hablando sobre las ventas totales de cada tienda, se obtuvo que la tienda número 1 tuvo una venta total de: 1150880400, la tienda número 2 tuvo un total de ventas estimado en 1116343500, la tienda número 3 un total de ventas estimado en: 1098019600, y finalmente la tienda número 4 tuvo unas ventas de 1038375700.
#
# Analisando los datos del ponderado de ventas para cada tienda, se puede decir que el producto más popular entre todas las tiendas es el microondas, por lo que representa un ingreso mayor en cuanto a ventas.
#
# Finalmente se analizó la calificación promedio de cada tienda y se obtuvo que las 4 tiendas tinen una calificación promedio que ronda las 4 estrellas de 5, en donde la calificación más baja fue para la tienda 4, que obtuvo un rating de 3.99 en promedio.
#
# Dado el exhaustivo análisis brindado en este documento, se puede decir con seguridad que la tienda número 4, aunque tenga un desempeño competente es la tienda que don Juan debe vender, ya que tiene menores ventas, menor calificación y los productos que vende son variados y no siguen ninguna tendencia por lo que no perdería ganancias que las otras tiendas no generen.
